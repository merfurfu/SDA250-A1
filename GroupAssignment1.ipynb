# %% [markdown]
# Katherine Korovnikov 301394667 - contributed code for Q2 & Q4 - edited all CETA sections
#
#
#
# Victoria Leung 301276986 - contributed code for Q5 & Q6 - edited and reformatted treaty of versailles secctions + completed assignment
#
#
# Rachel Way 301435818 - contributed code for Q1 & Q3 - edited all climate report sections

# %%
pwd
# Out:
# 'C:\\Users\\victo\\Documents\\GitHub\\assgn1'

# %%
import nltk

# %%
#Import corpus reader functionalities
from nltk.corpus import PlaintextCorpusReader
#Point to the path where you have some files
#Change this for your own path
corpus_root = "./data"

# %%
corpus_root
# Out:
# './data'

# %%
text = PlaintextCorpusReader(corpus_root, '.*')

# %%
treaty = PlaintextCorpusReader(corpus_root, '.*')

# %%
climateReport = text.words('climateReport.txt')

# %%
ceta = PlaintextCorpusReader(corpus_root, '.*')

# %%
ToV = treaty.words('versailles.txt')

# %%
ceta_words = ceta.words('cetaAgreement.txt')

# %%
climateReport
# Out:
# ['Where', 'We', 'Stand', ':', 'The', 'Integration', ...]

# %%
ToV
# Out:
# ['TREATY', 'OF', 'PEACE', 'WITH', 'GERMANY', '(', ...]

# %%
ceta_words
# Out:
# ['This', 'text', 'is', 'made', 'public', 'exclusively', ...]

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Climate Report

# %%
print("The length of the Climate Report is", len(climateReport), "words.")
# Out:
# The length of the Climate Report is 8061 words.

# %% [markdown]
# ### Treaty of Versailles (ToV)

# %%
print("The length of the Treaty of Versailles is", len(ToV))
# Out:
# The length of the Treaty of Versailles is 87142

# %% [markdown]
# ### CETA

# %%
print("The length of the Comprehensive Economic Trade Agreement(CETA) is", len(ceta_words), "words.")
# Out:
# The length of the Comprehensive Economic Trade Agreement(CETA) is 425775 words.

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Climate Report

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity(climateReport)
# Out:
# 0.21275276020344872

# %%
print("The lexical diversity is" , lexical_diversity(climateReport))
# Out:
# The lexical diversity is 0.21275276020344872

# %% [markdown]
# ### Treaty of Versailles (ToV)

# %%
def lexical_diversity(treaty):
    return len(set(treaty)) / len(treaty)
lexical_diversity(ToV)
# Out:
# 0.07072364646209635

# %%
print("the lexical diversity of the Treaty of Versailles is", lexical_diversity(ToV))
# Out:
# the lexical diversity of the Treaty of Versailles is 0.07072364646209635

# %% [markdown]
# ### CETA

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
#lexical diversity 

lexical_diversity(ceta_words)
# Out:
# 0.04363572309318302

# %%
print("The lexical diversity is" , lexical_diversity(ceta_words))
# Out:
# The lexical diversity is 0.04363572309318302

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Climate Report

# %%
climateSent = text.sents('climateReport.txt')

# %%
climateSent
# Out:
# [['Where', 'We', 'Stand', ':', 'The', 'Integration', 'of', 'Climate', 'Change', 'Education', 'in', 'Canadian', 'Schools', 'A', 'WORKING', 'PAPER', 'BY', 'BCCIC', 'CLIMATE', 'CHANGE'], ['November', '2021', 'By', 'Kylie', 'Schatz', 'Working', 'Paper'], ...]

# %%
longestSent = max(len(s) for s in climateSent)
[s for s in climateSent if len(s) == longestSent]
# Out:
# [['In',
#   'British',
#   'Columbia',
#   ',',
#   'the',
#   'Canadian',
#   'Centre',
#   'for',
#   'Policy',
#   'Alternatives',
#   '’',
#   'Climate',
#   'Justice',
#   'Project',
#   'has',
#   'created',
#   '“',
#   'Climate',
#   'Justice',
#   'in',
#   'BC',
#   ':',
#   'Lessons',
#   'for',
#   'Transformation',
#   ',”',
#   'a',
#   'resource',
#   'package',
#   'for',
#   'teachers',
#   'with',
#   'classroom',
#   '-',
#   'ready',
#   'materials',
#   'to',
#   'engage',
#   'students',
#   'in',
#   'discussions',
#   'on',
#   'the',
#   'intersection',
#   'between',
#   'climate',
#   'action',
#   'and',
#   'social',
#   'justice',
#   '.',
#   '³³',
#   'Based',
#   'on',
#   'BC',
#   '’',
#   's',
#   'local',
#   'communities',
#   ',',
#   'the',
#   'package',
#   'ties',
#   'together',
#   'the',
#   'issues',
#   'of',
#   'climate',
#   'change',
#   'and',
#   'rising',
#   'inequality',
#   'as',
#   'it',
#   'focuses',
#   'on',
# ...

# %%
print("The amount of words in the longest sentence is" , longestSent)
# Out:
# The amount of words in the longest sentence is 243

# %% [markdown]
# ### Treaty of Versailles (ToV)

# %%
treatySent = treaty.sents('versailles.txt')

# %%
treatySent
# Out:
# [['TREATY', 'OF', 'PEACE', 'WITH', 'GERMANY', '(', 'TREATY', 'OF', 'VERSAILLES', ')', 'Treaty', 'and', 'protocol', 'signed', 'at', 'Versailles', 'June', '28', ',', '1919', ';', 'protocol', 'signed', 'by', 'Germany', 'at', 'Paris', 'January', '10', ',', '1920', 'Treaty', 'submitted', 'to', 'the', 'Senate', 'by', 'the', 'President', 'of', 'the', 'United', 'States', 'for', 'advice', 'and', 'consent', 'to', 'ratification', 'July', '10', ',', '1919', ';', '1', 'Senate', 'resolutions', 'to', 'advise', 'and', 'consent', 'to', 'ratification', 'failed', 'of', 'adoption', 'November', '19', ',', '1919', ',', '2', 'and', 'March', '19', ',', '1920', ';', '3', 'treaty', 'returned', 'to', 'the', 'President', 'pursuant', 'to', 'resolution', 'of', 'March', '19', ',', '1920', '4', 'Protocol', 'of', 'June', '28', ',', '1919', ',', 'submitted', 'to', 'the', 'Senate', 'by', 'the', 'President', 'of', 'the', 'United', 'States', 'July', '31', ',', '1919', ';', '5', 'considered', 'by', 'the', 'Senate', 'Comm
# ...

# %%
longestSent = max(len(s) for s in treatySent)
[s for s in treatySent if len(s) == longestSent]
# Out:
# [['thence',
#   'the',
#   'administrative',
#   'boundary',
#   'of',
#   'Posnania',
#   'north',
#   '-',
#   'westwards',
#   'to',
#   'the',
#   'point',
#   'where',
#   'it',
#   'cuts',
#   'the',
#   'Rawitsch',
#   '-',
#   'Herrnstadt',
#   'railway',
#   ';',
#   'thence',
#   'to',
#   'the',
#   'point',
#   'where',
#   'the',
#   'administrative',
#   'boundary',
#   'of',
#   'Posnania',
#   'cuts',
#   'the',
#   'Reisen',
#   '-',
#   'Tschirnau',
#   'road',
#   ':',
#   'a',
#   'line',
#   'to',
#   'be',
#   'fixed',
#   'on',
#   'the',
#   'ground',
#   'passing',
#   'west',
#   'of',
#   'Triebusch',
#   'and',
#   'Gabel',
#   'and',
#   'east',
#   'of',
#   'Saborwitz',
#   ';',
#   'thence',
#   'the',
#   'administrative',
#   'boundary',
#   'of',
#   'Posnania',
#   'to',
#   'its',
#   'junction',
#   'with',
#   'the',
#   'eastern',
#   'administrative',
#   'boundary',
#   'of',
#   'the',
#   'Kreis',
#   'of',
#   'Fraustadt',
#   ';',
# ...

# %%
print("The amount of words in the longest sentence is", longestSent)
# Out:
# The amount of words in the longest sentence is 423

# %% [markdown]
# # CETA

# %%
# longest scentence
ceta_sent = ceta.sents('cetaAgreement.txt')

# %%
ceta_sent
# Out:
# [['This', 'text', 'is', 'made', 'public', 'exclusively', 'for', 'information', 'purposes', '.'], ['The', 'text', 'is', 'the', 'outcome', 'of', 'the', 'legal', 'review', 'conducted', 'by', 'the', 'Canadian', 'Government', 'and', 'the', 'European', 'Commission', 'and', 'will', 'be', 'translated', 'and', 'thereafter', 'subject', 'to', 'completion', 'of', 'the', 'internal', 'approval', 'processes', 'in', 'Canada', 'and', 'the', 'European', 'Union', '.'], ...]

# %%
longest_len = max(len(s) for s in ceta_sent)
[s for s in ceta_sent if len(s) == longest_len]
# Out:
# [['RECOGNISING',
#   'the',
#   'importance',
#   'of',
#   'international',
#   'security',
#   ',',
#   'democracy',
#   ',',
#   'human',
#   'rights',
#   'and',
#   'the',
#   'rule',
#   'of',
#   'law',
#   'for',
#   'the',
#   'development',
#   'of',
#   'international',
#   'trade',
#   'and',
#   'economic',
#   'cooperation',
#   ';',
#   'RECOGNISING',
#   'that',
#   'the',
#   'provisions',
#   'of',
#   'this',
#   'Agreement',
#   'preserve',
#   'the',
#   'right',
#   'of',
#   'the',
#   'Parties',
#   'to',
#   'regulate',
#   'within',
#   'their',
#   'territories',
#   'and',
#   'the',
#   'Parties',
#   '’',
#   'flexibility',
#   'to',
#   'achieve',
#   'legitimate',
#   'policy',
#   'objectives',
#   ',',
#   'such',
#   'as',
#   'public',
#   'health',
#   ',',
#   'safety',
#   ',',
#   'environment',
#   ',',
#   'public',
#   'morals',
#   'and',
#   'the',
#   'promotion',
#   'and',
#   'protection',
#   'of',
#   'cultural',
#   'diversity',
# ...

# %%
print("The amount of words is the longest sentence is", longest_len)
# Out:
# The amount of words is the longest sentence is 381

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Climate Report

# %%
from nltk.text import Text 

climateReportList = nltk.Text(text.words("climateReport.txt"))
climateReportList.collocations()
# Out:
# climate change; Climate Change; CLIMATE CHANGE; CANADIAN SCHOOLS;
# CHANGE EDUCATION; https ://; Secondary Schools; Science Curricula;
# Canadian Secondary; National Overview; Change Education; British
# Columbia; Climate Science; scientific consensus; change education;
# development opportunities; professional development; International
# Cooperation; First Nations; Accessed October

# %% [markdown]
# ### ToV

# %%
from nltk.text import Text  

treatyList = nltk.Text(treaty.words('versailles.txt'))
treatyList.collocations()
# Out:
# present Treaty; Associated Powers; MULTILATERAL AGREEMENTS; AGREEMENTS
# 1918; Principal Allied; German Government; Saar Basin; Reparation
# Commission; Contracting Parties; High Contracting; Mixed Arbitral;
# Clearing Office; Arbitral Tribunal; Germany undertakes; German
# nationals; three months; Free City; Associated Power; per cent;
# Clearing Offices

# %% [markdown]
# # CETA

# %%
from nltk.text import Text
cetaList = nltk.Text(ceta.words('cetaAgreement.txt'))
cetaList.collocations()
# Out:
# Industry Classification; Market access; Border Trade; European Union;
# National treatment; per cent; Existing Measures; Member State;
# services Sub; net weight; http ://; needs test; ISIC rev; Senior
# management; :// www; Party shall; access Level; works price;
# conformity assessment; transaction value

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Climate Report

# %%
import re
from nltk.text import Text
climateReportFD  = nltk.FreqDist(text.words('climateReport.txt'))
climateReportFD.most_common(10)
# Out:
# [(',', 460),
#  ('.', 399),
#  ('the', 270),
#  ('and', 257),
#  ('of', 173),
#  ('to', 163),
#  ('climate', 157),
#  ('in', 135),
#  ('change', 131),
#  ('-', 93)]

# %%
for w in a_wordlist:
    a_wordlist = [w for w in climateReportFD if w.islower()]
    a_wordlist = [w for w in a_wordlist if re.search('^[a]', w)]
    
i=0
while(i<10):
    print(a_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# and
# a
# as
# action
# are
# also
# an
# at
# about
# all

# %%
for w in a_wordlist:
    a_wordlist = [w for w in climateReportFD if w.islower()]
    a_wordlist = [w for w in a_wordlist if re.search('^[e]', w)]
    
i=0
while(i<10):
    print(a_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# education
# environmental
# each
# ecological
# environment
# example
# evidence
# enhance
# existing
# exists

# %%
for w in a_wordlist:
    a_wordlist = [w for w in climateReportFD if w.islower()]
    a_wordlist = [w for w in a_wordlist if re.search('^[i]', w)]
    
i=0
while(i<10):
    print(a_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# in
# is
# it
# into
# individual
# impacts
# information
# its
# important
# impact

# %%
for w in a_wordlist:
    a_wordlist = [w for w in climateReportFD if w.islower()]
    a_wordlist = [w for w in a_wordlist if re.search('^[o]', w)]
    
i=0
while(i<10):
    print(a_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# of
# on
# our
# or
# opportunities
# only
# other
# organizations
# one
# over

# %%
for w in a_wordlist:
    a_wordlist = [w for w in climateReportFD if w.islower()]
    a_wordlist = [w for w in a_wordlist if re.search('^[u]', w)]
    
i=0
while(i<10):
    print(a_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# up
# understanding
# us
# unit
# understand
# understood
# utilizing
# use
# upon
# underfunded

# %% [markdown]
# ### ToV

# %%
import re
from nltk.text import Text
treatyFD  = nltk.FreqDist(treaty.words('versailles.txt'))
treatyFD.most_common(10)
# Out:
# [('the', 7046),
#  ('of', 5039),
#  (',', 4239),
#  ('to', 2437),
#  ('and', 2306),
#  ('.', 2280),
#  ('in', 1652),
#  ('or', 1295),
#  ('be', 1291),
#  ('shall', 1016)]

# %%
a_wordlist = [w for w in treatyFD if w.islower()]
[w for w in a_wordlist if re.search('^[a]', w)]
# Out:
# ['and',
#  'a',
#  'as',
#  'any',
#  'all',
#  'at',
#  'are',
#  'an',
#  'above',
#  'accordance',
#  'after',
#  'amount',
#  'apply',
#  'against',
#  'administrative',
#  'about',
#  'authorities',
#  'account',
#  'also',
#  'appointed',
#  'administration',
#  'agrees',
#  'action',
#  'agreements',
#  'agree',
#  'authority',
#  'articles',
#  'applied',
#  'area',
#  'agreement',
#  'air',
#  'arising',
#  'aircraft',
#  'acquired',
#  'artistic',
#  'arrangements',
#  'accept',
#  'application',
#  'ante',
#  'age',
#  'adopted',
#  'arms',
#  'acts',
#  'allies',
#  'admitted',
#  'another',
#  'act',
#  'accessories',
#  'agreed',
#  'applicable',
#  'assets',
#  'anyone',
#  'acquire',
#  'amounts',
#  'among',
#  'average',
#  'accorded',
#  'allowed',
#  'annexed',
#  'annually',
#  'allow',
#  'archives',
#  'acceptance',
#  'arbitration',
#  'according',
#  'attached',
#  'animals',
#  'appoint',
#  'affecting',
#  'authorised',
#  'abrogation',
#  'accepts',
# ...

# %% [markdown]
# #### For A

# %%
#for i in range (9):
#    for w in a_wordlist:
#        a_wordlist = [w for w in treatyFD if w.islower()]
#        [w for w in a_wordlist if re.search('^[a]', w)]
#    print(i,w)

# i = 0
# while i < 9:
#     a_wordlist = sorted(w in treatyFD if re.search('^[a]', w))
#     print (a_wordlist[i])
#     i += 1
    
#applies the filter on wordlist everytime    
for w in a_wordlist:
    a_wordlist = [w for w in treatyFD if w.islower()]
    a_wordlist = [w for w in a_wordlist if re.search('^[a]', w)]

#cycles through 10 times and each time they print the word in position i
i=0
while(i<10):
    print(a_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# and
# a
# as
# any
# all
# at
# are
# an
# above
# accordance

# %% [markdown]
# #### For E

# %%
for w in e_wordlist:
    e_wordlist = [w for w in treatyFD if w.islower()]
    e_wordlist = [w for w in e_wordlist if re.search('^[e]', w)]
    
i=0
while(i<10):
    print(e_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# each
# enemy
# east
# entitled
# established
# effected
# execution
# either
# effect
# every

# %% [markdown]
# #### For I

# %%
for w in i_wordlist:
    i_wordlist = [w for w in treatyFD if w.islower()]
    i_wordlist = [w for w in i_wordlist if re.search('^[i]', w)]
    
i=0
while(i<10):
    print(i_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# in
# into
# is
# its
# it
# interests
# if
# including
# international
# interest

# %% [markdown]
# #### For O

# %%
for w in o_wordlist:
    o_wordlist = [w for w in treatyFD if w.islower()]
    o_wordlist = [w for w in o_wordlist if re.search('^[o]', w)]
    
i=0
while(i<10):
    print(o_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# of
# or
# on
# other
# one
# over
# out
# obligations
# order
# obligation

# %% [markdown]
# #### For U

# %%
for w in u_wordlist:
    u_wordlist = [w for w in treatyFD if w.islower()]
    u_wordlist = [w for w in u_wordlist if re.search('^[u]', w)]
    
i=0
while(i<10):
    print(u_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# under
# undertakes
# upon
# up
# use
# until
# undertake
# used
# unless
# understood

# %% [markdown]
# ## CETA

# %%
import re
from nltk.text import Text
cetaFD  = nltk.FreqDist(ceta.words('cetaAgreement.txt'))
cetaFD.most_common(10)
# Out:
# [('.', 18744),
#  (',', 17687),
#  ('of', 17190),
#  ('the', 16959),
#  ('and', 9532),
#  (':', 8647),
#  ('to', 7342),
#  ('-', 7181),
#  ('or', 6819),
#  ('(', 6775)]

# %%
#  Top ten words that start with the vowel A
for w in a_wordlist:
    a_wordlist = [w for w in cetaFD if w.islower()]
    a_wordlist = [w for w in a_wordlist if re.search('^[a]', w)]
    
i=0
while(i<10):
    print(a_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# and
# a
# any
# as
# an
# access
# are
# at
# adopt
# all

# %%
# Top ten words that start with the vowel E
for w in a_wordlist:
    a_wordlist = [w for w in cetaFD if w.islower()]
    a_wordlist = [w for w in a_wordlist if re.search('^[e]', w)]
    
i=0
while(i<10):
    print(a_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# ex
# exceed
# entity
# established
# each
# existing
# economic
# except
# enterprise
# entities

# %%
# Top ten words that start with the vowel I
for w in a_wordlist:
    i_wordlist = [w for w in cetaFD if w.islower()]
    i_wordlist = [w for w in i_wordlist if re.search('^[i]', w)]
    
i=0
while(i<10):
    print(i_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# in
# is
# its
# including
# if
# information
# it
# insurance
# into
# investment

# %%
# Top ten words that start with the vowel O

for w in a_wordlist:
    o_wordlist = [w for w in cetaFD if w.islower()]
    o_wordlist = [w for w in o_wordlist if re.search('^[o]', w)]
    
i=0
while(i<10):
    print(o_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# of
# or
# other
# on
# originating
# out
# one
# only
# origin
# order

# %%
# Top ten words that start with the vowel U

for w in a_wordlist:
    u_wordlist = [w for w in cetaFD if w.islower()]
    u_wordlist = [w for w in u_wordlist if re.search('^[u]', w)]
    
i=0
while(i<10):
    print(u_wordlist[i])
        #if w == "after": break
    i +=1
# Out:
# under
# used
# use
# up
# unless
# und
# upon
# undertaken
# undertaking
# using

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Climate Report

# %%
from nltk import word_tokenize

# %%
longStemSent = max(climateSent, key=len)

# %%
print(longStemSent)
# Out:
# ['In', 'British', 'Columbia', ',', 'the', 'Canadian', 'Centre', 'for', 'Policy', 'Alternatives', '’', 'Climate', 'Justice', 'Project', 'has', 'created', '“', 'Climate', 'Justice', 'in', 'BC', ':', 'Lessons', 'for', 'Transformation', ',”', 'a', 'resource', 'package', 'for', 'teachers', 'with', 'classroom', '-', 'ready', 'materials', 'to', 'engage', 'students', 'in', 'discussions', 'on', 'the', 'intersection', 'between', 'climate', 'action', 'and', 'social', 'justice', '.', '³³', 'Based', 'on', 'BC', '’', 's', 'local', 'communities', ',', 'the', 'package', 'ties', 'together', 'the', 'issues', 'of', 'climate', 'change', 'and', 'rising', 'inequality', 'as', 'it', 'focuses', 'on', 'allowing', 'students', 'an', 'opportunity', 'to', 're', '-', 'imagine', 'the', 'systems', 'around', 'them', '.', '³⁴', 'While', 'it', 'is', 'tied', 'to', 'prescribed', 'learning', 'outcomes', 'in', 'the', 'BC', 'Curriculum', ',', 'it', 'provides', 'teachers', 'with', 'the', 'background', 'to', 'tie', 'climate',
# ...

# %%
def stem(word):
    regexp = r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)?$'
    stem, suffix = re.findall(regexp, str(word))[0]
    return stem

raw = str(longStemSent)

tokens = word_tokenize(raw)
[stem(t) for t in tokens]
# Out:
# ['[',
#  "'In",
#  "'",
#  ',',
#  "'British",
#  "'",
#  ',',
#  "'Columbia",
#  "'",
#  ',',
#  "'",
#  ',',
#  "'",
#  ',',
#  "'the",
#  "'",
#  ',',
#  "'Canadian",
#  "'",
#  ',',
#  "'Centre",
#  "'",
#  ',',
#  "'for",
#  "'",
#  ',',
#  "'Policy",
#  "'",
#  ',',
#  "'Alternativ",
#  "'",
#  ',',
#  "'",
#  '’',
#  "'",
#  ',',
#  "'Climate",
#  "'",
#  ',',
#  "'Justice",
#  "'",
#  ',',
#  "'Project",
#  "'",
#  ',',
#  "'ha",
#  "'",
#  ',',
#  "'creat",
#  "'",
#  ',',
#  "'",
#  '“',
#  "'",
#  ',',
#  "'Climate",
#  "'",
#  ',',
#  "'Justice",
#  "'",
#  ',',
#  "'in",
#  "'",
#  ',',
#  "'BC",
#  "'",
#  ',',
#  "'",
#  ':',
#  "'",
#  ',',
#  "'Lesson",
#  "'",
#  ',',
#  "'for",
#  "'",
#  ',',
#  "'Transformation",
#  "'",
#  ',',
#  "'",
#  ',',
#  '”',
#  "'",
#  ',',
#  "'",
#  'a',
#  "'",
#  ',',
#  "'resource",
#  "'",
#  ',',
#  "'package",
#  "'",
#  ',',
#  "'for",
#  "'",
#  ',',
#  "'teacher",
#  "'",
#  ',',
#  "'with",
#  "'",
#  ',',
#  "'classroom",
# ...

# %% [markdown]
# ### ToV

# %%
treatyStemSent = max(treatySent, key=len)

# %%
print(len(treatyStemSent))
# Out:
# 423

# %%
treatyRaw = str(treatyStemSent)

tokens = word_tokenize(treatyRaw)
[stem(t) for t in tokens]
# Out:
# ['[',
#  "'thence",
#  "'",
#  ',',
#  "'the",
#  "'",
#  ',',
#  "'administrat",
#  "'",
#  ',',
#  "'boundary",
#  "'",
#  ',',
#  "'of",
#  "'",
#  ',',
#  "'Posnania",
#  "'",
#  ',',
#  "'north",
#  "'",
#  ',',
#  "'-",
#  "'",
#  ',',
#  "'westward",
#  "'",
#  ',',
#  "'to",
#  "'",
#  ',',
#  "'the",
#  "'",
#  ',',
#  "'point",
#  "'",
#  ',',
#  "'where",
#  "'",
#  ',',
#  "'it",
#  "'",
#  ',',
#  "'cut",
#  "'",
#  ',',
#  "'the",
#  "'",
#  ',',
#  "'Rawitsch",
#  "'",
#  ',',
#  "'-",
#  "'",
#  ',',
#  "'Herrnstadt",
#  "'",
#  ',',
#  "'railway",
#  "'",
#  ',',
#  "'",
#  ';',
#  "'",
#  ',',
#  "'thence",
#  "'",
#  ',',
#  "'to",
#  "'",
#  ',',
#  "'the",
#  "'",
#  ',',
#  "'point",
#  "'",
#  ',',
#  "'where",
#  "'",
#  ',',
#  "'the",
#  "'",
#  ',',
#  "'administrat",
#  "'",
#  ',',
#  "'boundary",
#  "'",
#  ',',
#  "'of",
#  "'",
#  ',',
#  "'Posnania",
#  "'",
#  ',',
#  "'cut",
#  "'",
#  ',',
#  "'the",
#  "'",
#  ',',
#  "'Reisen",
#  "'",
#  ',',
# ...

# %% [markdown]
# ## CETA

# %%
# stemmed version of the longest sentence
from nltk import word_tokenize

# %%
longSentStemCeta = max(ceta_sent, key=len)

# %%
print(longSentStemCeta)
# Out:
# ['RECOGNISING', 'the', 'importance', 'of', 'international', 'security', ',', 'democracy', ',', 'human', 'rights', 'and', 'the', 'rule', 'of', 'law', 'for', 'the', 'development', 'of', 'international', 'trade', 'and', 'economic', 'cooperation', ';', 'RECOGNISING', 'that', 'the', 'provisions', 'of', 'this', 'Agreement', 'preserve', 'the', 'right', 'of', 'the', 'Parties', 'to', 'regulate', 'within', 'their', 'territories', 'and', 'the', 'Parties', '’', 'flexibility', 'to', 'achieve', 'legitimate', 'policy', 'objectives', ',', 'such', 'as', 'public', 'health', ',', 'safety', ',', 'environment', ',', 'public', 'morals', 'and', 'the', 'promotion', 'and', 'protection', 'of', 'cultural', 'diversity', ';', 'AFFIRMING', 'their', 'commitments', 'as', 'parties', 'to', 'the', 'UNESCO', 'Convention', 'on', 'the', 'Protection', 'and', 'Promotion', 'of', 'the', 'Diversity', 'of', 'Cultural', 'Expressions', ',', 'done', 'at', 'Paris', 'on', '20', 'October', '2005', ',', 'and', 'recognising', 'that', 
# ...

# %%
def stem(word):
    regexp = r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)?$'
    stem, suffix = re.findall(regexp, str(word))[0]
    return stem

cetaRaw = str(longSentStemCeta)

tokens = word_tokenize(cetaRaw)
[stem(t) for t in tokens]
# Out:
# ['[',
#  "'RECOGNISING",
#  "'",
#  ',',
#  "'the",
#  "'",
#  ',',
#  "'importance",
#  "'",
#  ',',
#  "'of",
#  "'",
#  ',',
#  "'international",
#  "'",
#  ',',
#  "'security",
#  "'",
#  ',',
#  "'",
#  ',',
#  "'",
#  ',',
#  "'democracy",
#  "'",
#  ',',
#  "'",
#  ',',
#  "'",
#  ',',
#  "'human",
#  "'",
#  ',',
#  "'right",
#  "'",
#  ',',
#  "'and",
#  "'",
#  ',',
#  "'the",
#  "'",
#  ',',
#  "'rule",
#  "'",
#  ',',
#  "'of",
#  "'",
#  ',',
#  "'law",
#  "'",
#  ',',
#  "'for",
#  "'",
#  ',',
#  "'the",
#  "'",
#  ',',
#  "'develop",
#  "'",
#  ',',
#  "'of",
#  "'",
#  ',',
#  "'international",
#  "'",
#  ',',
#  "'trade",
#  "'",
#  ',',
#  "'and",
#  "'",
#  ',',
#  "'economic",
#  "'",
#  ',',
#  "'cooperation",
#  "'",
#  ',',
#  "'",
#  ';',
#  "'",
#  ',',
#  "'RECOGNISING",
#  "'",
#  ',',
#  "'that",
#  "'",
#  ',',
#  "'the",
#  "'",
#  ',',
#  "'provision",
#  "'",
#  ',',
#  "'of",
#  "'",
#  ',',
#  "'thi",
#  "'",
#  ',',
#  "'Agree",
#  "'",
#  ',',
# ...
